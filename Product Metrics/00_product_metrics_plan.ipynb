# %% [markdown]
# <div style="text-align: center; padding: 2em 1em; background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); border-radius: 12px; color: white; margin-bottom: 2em;">
#   <h1 style="margin: 0; font-size: 2.5em; font-weight: 600; letter-spacing: -0.02em;">Продуктовые метрики в игровой индустрии</h1>
#   <p style="margin: 0.5em 0 0 0; font-size: 1.2em; opacity: 0.95;">Полное руководство по метрикам для игрового аналитика</p>
# </div>
#
# <div style="padding: 1.5em; background: #f8f9fa; border-left: 4px solid #667eea; border-radius: 6px; margin: 1em 0;">
#   <p style="margin: 0; color: #2c3e50; line-height: 1.6; font-weight: 400;">
#     <strong>Цель ноутбука:</strong> детальное описание всех продуктовых метрик, используемых в игровой индустрии:
#     как они считаются, зачем нужны, что показывают, на что влияют и что на них влияет.
#   </p>
# </div>

# %% [markdown]
# # 📋 Оглавление
#
# ## 1. Метрики удержания (Retention Metrics)
#
# ### 1.1. Day-1 Retention (D1 Retention)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки и нормальные значения
# - Как улучшить
#
# ### 1.2. Day-7 Retention (D7 Retention)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки и нормальные значения
# - Как улучшить
#
# ### 1.3. Day-30 Retention (D30 Retention)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки и нормальные значения
# - Как улучшить
#
# ### 1.4. Rolling Retention
# - Определение и формула расчета
# - Отличие от классического retention
# - Когда использовать
# - Преимущества и недостатки
#
# ### 1.5. Unbounded Retention
# - Определение и формула расчета
# - Когда использовать
# - Преимущества и недостатки
#
# ### 1.6. Return Rate
# - Определение и формула расчета
# - Отличие от retention
# - Что показывает
#
# ### 1.7. Churn Rate (Отток)
# - Определение и формула расчета
# - Связь с retention
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Как снизить
#
# ### 1.8. Survival Rate (Кривая выживаемости)
# - Определение и построение
# - Что показывает
# - Как интерпретировать
#
# ## 2. Метрики вовлеченности (Engagement Metrics)
#
# ### 2.1. Daily Active Users (DAU)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Сезонность и паттерны
# - Как увеличить
#
# ### 2.2. Weekly Active Users (WAU)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Связь с DAU
#
# ### 2.3. Monthly Active Users (MAU)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 2.4. DAU/MAU Ratio (Stickiness)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает (частота использования)
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
# - Как улучшить
#
# ### 2.5. Session Count (Количество сессий)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 2.6. Average Sessions per User
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 2.7. Session Duration (Длительность сессии)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
# - Как увеличить
#
# ### 2.8. Average Session Duration per User
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
#
# ### 2.9. Time in Game (Общее время в игре)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 2.10. Average Time Between Sessions
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Что на нее влияет
#
# ### 2.11. Playtime Distribution
# - Определение и построение
# - Что показывает
# - Как интерпретировать
#
# ### 2.12. Feature Adoption Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 2.13. Feature Usage Frequency
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
#
# ### 2.14. Core Loop Completion Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 3. Метрики монетизации (Monetization Metrics)
#
# ### 3.1. Revenue (Выручка)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Разбивка по источникам
#
# ### 3.2. ARPU (Average Revenue Per User)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки по жанрам
# - Как увеличить
#
# ### 3.3. ARPPU (Average Revenue Per Paying User)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
# - Как увеличить
#
# ### 3.4. LTV (Lifetime Value)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Методы расчета (когортный, прогнозный, исторический)
# - Бенчмарки
# - Как увеличить
#
# ### 3.5. Predicted LTV (pLTV)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Методы прогнозирования
# - Точность прогноза
#
# ### 3.6. Paying User Rate (Conversion Rate)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки по жанрам
# - Как увеличить
#
# ### 3.7. First Purchase Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Как увеличить
#
# ### 3.8. Repeat Purchase Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 3.9. Average Order Value (AOV)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Как увеличить
#
# ### 3.10. Purchase Frequency
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 3.11. Time to First Purchase (TTFP)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
# - Как уменьшить
#
# ### 3.12. Purchase Funnel Conversion
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как улучшить
#
# ### 3.13. Revenue per Session
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 3.14. Revenue per Day
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Сезонность
#
# ### 3.15. IAP Revenue Share
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 3.16. Ad Revenue Share
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 3.17. Revenue Concentration (Gini Coefficient)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 3.18. Whale Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 3.19. Dolphin Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
#
# ### 3.20. Minnow Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
#
# ### 3.21. Revenue Retention
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 4. Метрики привлечения пользователей (User Acquisition Metrics)
#
# ### 4.1. New Users (Новые пользователи)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 4.2. Install Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 4.3. CPI (Cost Per Install)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки по платформам
# - Как снизить
#
# ### 4.4. CPA (Cost Per Acquisition)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Отличие от CPI
# - На что влияет
#
# ### 4.5. CAC (Customer Acquisition Cost)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Связь с LTV
# - Как снизить
#
# ### 4.6. ROAS (Return on Ad Spend)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
# - Как увеличить
#
# ### 4.7. ROI (Return on Investment)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Отличие от ROAS
# - На что влияет
#
# ### 4.8. LTV/CAC Ratio
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Бенчмарки (здоровые значения)
# - Как улучшить
#
# ### 4.9. Payback Period
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Бенчмарки
#
# ### 4.10. Organic vs Paid Users
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 4.11. Organic Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 4.12. Referral Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 4.13. Attribution Window
# - Определение и концепция
# - Зачем нужна метрика
# - Что показывает
# - Как выбрать
#
# ### 4.14. First Touch Attribution
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Преимущества и недостатки
#
# ### 4.15. Last Touch Attribution
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Преимущества и недостатки
#
# ### 4.16. Multi-Touch Attribution
# - Определение и концепция
# - Зачем нужна метрика
# - Что показывает
# - Методы распределения
#
# ## 5. Социальные и виральные метрики (Social & Viral Metrics)
#
# ### 5.1. K-Factor (Viral Coefficient)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки (K>1 = вирусный рост)
# - Как увеличить
#
# ### 5.2. Viral Cycle Time
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 5.3. Share Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 5.4. Invite Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 5.5. Invite Acceptance Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 5.6. Social Features Usage
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 5.7. Friend Count Distribution
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
#
# ### 5.8. Multiplayer Session Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 6. Метрики прогрессии (Progression Metrics)
#
# ### 6.1. Level Completion Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 6.2. Average Level Reached
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 6.3. Max Level Reached Distribution
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 6.4. Level Drop-off Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как снизить
#
# ### 6.5. Time to Level X
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 6.6. Progression Velocity
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 6.7. Tutorial Completion Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
# - Как увеличить
#
# ### 6.8. Tutorial Drop-off Points
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 6.9. Achievement Unlock Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 6.10. Achievement Completion Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 6.11. Collection Completion Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 6.12. Skill/XP Progression Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 7. Метрики воронок (Funnel Metrics)
#
# ### 7.1. Onboarding Funnel
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как улучшить
#
# ### 7.2. Purchase Funnel
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как улучшить
#
# ### 7.3. Feature Discovery Funnel
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 7.4. Conversion Rate by Step
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 7.5. Drop-off Rate by Step
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 7.6. Funnel Efficiency
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 8. Когортные метрики (Cohort Metrics)
#
# ### 8.1. Cohort Retention Curve
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 8.2. Cohort Revenue Curve
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 8.3. Cohort LTV
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как рассчитать
#
# ### 8.4. Cohort ARPU
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 8.5. Cohort Comparison
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 8.6. Cohort Segmentation
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Типы сегментации
#
# ## 9. Метрики баланса игры (Game Balance Metrics)
#
# ### 9.1. Win Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
#
# ### 9.2. Average Match Duration
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 9.3. Difficulty Curve
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 9.4. Attempts to Complete
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 9.5. Power Curve
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 9.6. Resource Economy Balance
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как анализировать
#
# ### 9.7. Item Usage Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 9.8. Item Purchase Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 9.9. Meta Balance (для PvP игр)
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как анализировать
#
# ### 9.10. Skill Gap Analysis
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ## 10. Метрики событий и действий (Event & Action Metrics)
#
# ### 10.1. Event Count
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 10.2. Event Frequency
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 10.3. Unique Event Users
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 10.4. Event Conversion Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 10.5. Time to Event
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 10.6. Event Sequence Analysis
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ## 11. Метрики контента (Content Metrics)
#
# ### 11.1. Content Consumption Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 11.2. Content Completion Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 11.3. Content Replay Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 11.4. Content Difficulty Distribution
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 11.5. Content Popularity Score
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 11.6. Update/Event Participation Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 12. Метрики рекламы (Advertising Metrics)
#
# ### 12.1. Ad Impressions
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 12.2. Ad Click Rate (CTR)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
#
# ### 12.3. Ad Completion Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 12.4. Ad Revenue per User
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 12.5. Ad Revenue per Impression
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 12.6. Ad Frequency
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 12.7. Ad Fatigue Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как снизить
#
# ### 12.8. Rewarded Video Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 12.9. Interstitial Ad Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 12.10. Banner Ad Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 13. Метрики технической производительности (Technical Performance Metrics)
#
# ### 13.1. Crash Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
# - Как снизить
#
# ### 13.2. Load Time
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
#
# ### 13.3. Frame Rate (FPS)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Бенчмарки
#
# ### 13.4. API Response Time
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 13.5. Error Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 13.6. Network Latency
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 13.7. Device Performance Distribution
# - Определение и построение
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 13.8. Memory Usage
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 13.9. Battery Drain Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 14. Метрики поддержки и качества (Support & Quality Metrics)
#
# ### 14.1. Support Ticket Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 14.2. Support Resolution Time
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 14.3. User Satisfaction Score (CSAT)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 14.4. Net Promoter Score (NPS)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ### 14.5. App Store Rating
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
# - Как улучшить
#
# ### 14.6. App Store Review Sentiment
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как анализировать
#
# ### 14.7. Bug Report Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 14.8. Refund Rate
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Что на нее влияет
#
# ## 15. Композитные и агрегированные метрики (Composite & Aggregated Metrics)
#
# ### 15.1. Health Score
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как рассчитать
#
# ### 15.2. Engagement Score
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как рассчитать
#
# ### 15.3. Retention Score
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как рассчитать
#
# ### 15.4. Monetization Score
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как рассчитать
#
# ### 15.5. Player Value Score
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как рассчитать
#
# ### 15.6. Game Health Index
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как рассчитать
#
# ## 16. Метрики сегментации (Segmentation Metrics)
#
# ### 16.1. User Segments (Whale, Dolphin, Minnow, etc.)
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 16.2. Behavioral Segments
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Типы сегментов
#
# ### 16.3. Engagement Segments
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 16.4. Retention Segments
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 16.5. Monetization Segments
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 16.6. Lifecycle Segments
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Типы сегментов (New, Active, At-Risk, Churned, Resurrected)
#
# ### 16.7. Geographic Segments
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 16.8. Platform Segments
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 16.9. Device Segments
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ## 17. Метрики времени (Time-based Metrics)
#
# ### 17.1. Peak Hours
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 17.2. Day of Week Patterns
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 17.3. Seasonal Patterns
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 17.4. Time to Action
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 17.5. Time to Value
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 18. Метрики сравнения и бенчмарки (Comparison & Benchmark Metrics)
#
# ### 18.1. Industry Benchmarks
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Источники бенчмарков
#
# ### 18.2. Genre Benchmarks
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Бенчмарки по жанрам
#
# ### 18.3. Platform Benchmarks
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Бенчмарки по платформам
#
# ### 18.4. Competitive Analysis Metrics
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 18.5. Year-over-Year (YoY) Growth
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 18.6. Month-over-Month (MoM) Growth
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 18.7. Week-over-Week (WoW) Growth
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ## 19. Метрики экспериментов (Experiment Metrics)
#
# ### 19.1. Treatment Effect
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
#
# ### 19.2. Statistical Significance
# - Определение и концепция
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 19.3. Effect Size
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 19.4. Confidence Interval
# - Определение и концепция
# - Зачем нужна метрика
# - Что показывает
# - Как интерпретировать
#
# ### 19.5. Power Analysis
# - Определение и концепция
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 19.6. Sample Size Calculation
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Как рассчитать
#
# ### 19.7. MDE (Minimum Detectable Effect)
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 19.8. Experiment Duration
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как рассчитать
#
# ## 20. Продвинутые аналитические метрики (Advanced Analytics Metrics)
#
# ### 20.1. Predictive Metrics (ML-based)
# - Определение и концепция
# - Зачем нужна метрика
# - Что показывает
# - Методы построения
#
# ### 20.2. Churn Prediction Score
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как использовать
#
# ### 20.3. Purchase Propensity Score
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Как использовать
#
# ### 20.4. User Lifetime Prediction
# - Определение и формула расчета
# - Зачем нужна метрика
# - Что показывает
# - На что влияет
# - Методы прогнозирования
#
# ### 20.5. Clustering Metrics
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 20.6. Anomaly Detection Metrics
# - Определение и методология
# - Зачем нужна метрика
# - Что показывает
# - Как использовать
#
# ### 20.7. Causal Inference Metrics
# - Определение и концепция
# - Зачем нужна метрика
# - Что показывает
# - Методы анализа
#
# ## 21. Метрики для специфических жанров игр
#
# ### 21.1. Метрики для Match-3 игр
# - Специфические метрики жанра
# - Что показывает
# - Как использовать
#
# ### 21.2. Метрики для RPG игр
# - Специфические метрики жанра
# - Что показывает
# - Как использовать
#
# ### 21.3. Метрики для Strategy игр
# - Специфические метрики жанра
# - Что показывает
# - Как использовать
#
# ### 21.4. Метрики для Battle Royale игр
# - Специфические метрики жанра
# - Что показывает
# - Как использовать
#
# ### 21.5. Метрики для Idle/Incremental игр
# - Специфические метрики жанра
# - Что показывает
# - Как использовать
#
# ### 21.6. Метрики для Social Casino игр
# - Специфические метрики жанра
# - Что показывает
# - Как использовать
#
# ### 21.7. Метрики для Hypercasual игр
# - Специфические метрики жанра
# - Что показывает
# - Как использовать
#
# ### 21.8. Метрики для Puzzle игр
# - Специфические метрики жанра
# - Что показывает
# - Как использовать
#
# ## 22. Методология расчета и анализа
#
# ### 22.1. Методы расчета метрик
# - SQL запросы
# - Python/Pandas расчеты
# - Статистические методы
#
# ### 22.2. Визуализация метрик
# - Типы графиков
# - Best practices
# - Инструменты
#
# ### 22.3. Дашборды и отчеты
# - Структура дашбордов
# - Ключевые метрики для дашбордов
# - Best practices
#
# ### 22.4. Анализ трендов
# - Методы анализа
# - Интерпретация
# - Прогнозирование
#
# ### 22.5. Корреляционный анализ
# - Методы анализа
# - Интерпретация
# - Причинно-следственные связи
#
# ### 22.6. Сегментационный анализ
# - Методы сегментации
# - Интерпретация
# - Применение
#
# ## 23. Практические кейсы и примеры
#
# ### 23.1. Кейс: Улучшение Retention
# - Проблема
# - Анализ метрик
# - Решение
# - Результаты
#
# ### 23.2. Кейс: Увеличение Monetization
# - Проблема
# - Анализ метрик
# - Решение
# - Результаты
#
# ### 23.3. Кейс: Оптимизация User Acquisition
# - Проблема
# - Анализ метрик
# - Решение
# - Результаты
#
# ### 23.4. Кейс: Балансировка игры
# - Проблема
# - Анализ метрик
# - Решение
# - Результаты
#
# ### 23.5. Кейс: Анализ A/B теста
# - Проблема
# - Анализ метрик
# - Решение
# - Результаты
#
# ---
#
# <div style="padding: 1.5em; background: #e8f5e9; border-left: 4px solid #4caf50; border-radius: 6px; margin: 1em 0;">
#   <p style="margin: 0; color: #2c3e50; line-height: 1.6; font-weight: 400;">
#     <strong>Итого:</strong> План включает <strong>23 основных раздела</strong> с <strong>более чем 200 метриками</strong>,
#     каждая из которых будет детально описана с формулами, примерами, бенчмарками и практическими рекомендациями.
#   </p>
# </div>
